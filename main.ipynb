# %%
import pandas as pd

# %%
df = pd.read_csv("data.csv")

df.head()
# Out:
#                           status_id status_type status_published  \
# 0  246675545449582_1649696485147474       video   4/22/2018 6:00
# 1  246675545449582_1649426988507757       photo  4/21/2018 22:45
# 2  246675545449582_1648730588577397       video   4/21/2018 6:17
# 3  246675545449582_1648576705259452       photo   4/21/2018 2:29
# 4  246675545449582_1645700502213739       photo   4/18/2018 3:22
#
#    num_reactions  num_comments  num_shares  num_likes  num_loves  num_wows  \
# 0            529           512         262        432         92         3
# 1            150             0           0        150          0         0
# 2            227           236          57        204         21         1
# 3            111             0           0        111          0         0
# 4            213             0           0        204          9         0
#
#    num_hahas  num_sads  num_angrys  Column1  Column2  Column3  Column4
# ...

# %%
df.shape
# Out:
# (7050, 16)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7050 entries, 0 to 7049
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   status_id         7050 non-null   object
#  1   status_type       7050 non-null   object
#  2   status_published  7050 non-null   object
#  3   num_reactions     7050 non-null   int64
#  4   num_comments      7050 non-null   int64
#  5   num_shares        7050 non-null   int64
#  6   num_likes         7050 non-null   int64
#  7   num_loves         7050 non-null   int64
#  8   num_wows          7050 non-null   int64
#  9   num_hahas         7050 non-null   int64
#  10  num_sads          7050 non-null   int64
#  11  num_angrys        7050 non-null   int64
#  12  Column1           0 non-null      float64
#  13  Column2           0 non-null      float64
#  14  Column3           0 non-null      float64
#  15  Column4           0 non-null      float64
# ...

# %%
df.describe()
# Out:
#        num_reactions  num_comments   num_shares    num_likes    num_loves  \
# count    7050.000000   7050.000000  7050.000000  7050.000000  7050.000000
# mean      230.117163    224.356028    40.022553   215.043121    12.728652
# std       462.625309    889.636820   131.599965   449.472357    39.972930
# min         0.000000      0.000000     0.000000     0.000000     0.000000
# 25%        17.000000      0.000000     0.000000    17.000000     0.000000
# 50%        59.500000      4.000000     0.000000    58.000000     0.000000
# 75%       219.000000     23.000000     4.000000   184.750000     3.000000
# max      4710.000000  20990.000000  3424.000000  4710.000000   657.000000
#
#           num_wows    num_hahas     num_sads   num_angrys  Column1  Column2  \
# count  7050.000000  7050.000000  7050.000000  7050.000000      0.0      0.0
# mean      1.289362     0.696454     0.243688     0.113191      NaN      NaN
# ...

# %%
df = df.drop(columns=["Column1","Column2","Column3","Column4"])

# %%
df.isna().sum()
# Out:
# status_id           0
# status_type         0
# status_published    0
# num_reactions       0
# num_comments        0
# num_shares          0
# num_likes           0
# num_loves           0
# num_wows            0
# num_hahas           0
# num_sads            0
# num_angrys          0
# dtype: int64

# %%
reactions = ['num_likes', 'num_loves', 'num_wows','num_hahas','num_sads','num_angrys']

sum_reactions = df[reactions].sum(axis=1)

# %%
df[df["num_reactions"] != sum_reactions]
# Out:
#                             status_id status_type status_published  \
# 238  246675545449582_1331955210254938       video   6/25/2017 7:42
# 247  246675545449582_1320853268031799       photo  6/13/2017 23:17
# 248  246675545449582_1319907678126358       photo   6/13/2017 1:31
# 251  246675545449582_1319045328212593       photo   6/12/2017 5:08
# 253  246675545449582_1318160668301059       photo   6/11/2017 7:04
# 254  246675545449582_1317164368400689       photo   6/10/2017 8:19
# 256  246675545449582_1316848781765581       photo   6/10/2017 1:08
# 257  246675545449582_1315331711917288       photo    6/8/2017 9:26
# 293  246675545449582_1262985247151935       video   4/20/2017 2:36
#
#      num_reactions  num_comments  num_shares  num_likes  num_loves  num_wows  \
# 238            885           462          26        659        220         0
# 247            264             2           0        256          2         5
# ...

# %%
df["num_reactions"]=sum_reactions

# %%
df.shape
# Out:
# (7050, 12)

# %% [markdown]
# # Preprocess the Data

# %%
df["status_type"].unique()
# Out:
# array(['video', 'photo', 'link', 'status'], dtype=object)

# %%
df["status_type"] = df["status_type"].map({"video": 0, "photo": 1,"link": 2, "status": 3})

# %%
df.drop(columns=["status_id","status_published"],inplace=True)

# %%
X = df
y = df["status_type"]

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

data_scaled = scaler.fit_transform(X)

# %%
data_scaled
# Out:
# array([[-1.1058511 ,  0.64611151,  0.32335035, ...,  0.07671305,
#          0.47357035, -0.15574803],
#        [ 0.30933319, -0.1731863 , -0.25220622, ..., -0.17600986,
#         -0.152587  , -0.15574803],
#        [-1.1058511 , -0.00673266,  0.01308938, ...,  0.07671305,
#         -0.152587  , -0.15574803],
#        ...,
#        [ 0.30933319, -0.49312318, -0.25220622, ..., -0.17600986,
#         -0.152587  , -0.15574803],
#        [ 0.30933319,  0.26132257, -0.23871662, ..., -0.17600986,
#         -0.152587  , -0.15574803],
#        [ 0.30933319, -0.46069715, -0.25220622, ..., -0.17600986,
#         -0.152587  , -0.15574803]])

# %%
from sklearn.decomposition import PCA

# Create PCA instance: model
pca = PCA()

# Apply the fit_transform method of model to grains: pca_features
pca_features = pca.fit_transform(X)

# %%
pca_features
# Out:
# array([[ 3.72670382e+02,  3.08271466e+02,  2.00897432e+02, ...,
#         -6.51456713e-01, -3.16451192e-01,  7.40174588e-12],
#        [-2.42585096e+02, -5.97837783e+01, -1.79519475e+01, ...,
#         -1.55022693e-02,  1.47566310e-01,  5.20805621e-13],
#        [ 1.15016984e+01, -1.17198050e+01,  1.83607427e+01, ...,
#         -1.56352030e-01, -7.21193885e-01,  2.05085948e-12],
#        ...,
#        [-2.81063033e+02, -2.66106248e+02, -1.08998616e+01, ...,
#         -1.94013717e-02,  1.76925915e-01,  5.39512879e-13],
#        [-1.76777344e+02,  2.16128292e+02, -6.62206249e+00, ...,
#         -2.97990708e-02,  1.39156848e-01,  8.34887715e-13],
#        [-2.77081352e+02, -2.44582896e+02, -1.19916340e+01, ...,
#         -1.38129701e-02,  1.69696459e-01,  4.49917881e-13]])

# %%
from sklearn.pipeline import make_pipeline
import matplotlib.pyplot as plt

pipeline = make_pipeline(scaler,pca)

# Fit the pipeline to 'samples'
pipeline.fit(X)

# Plot the explained variances
features = range(pca.n_components_)
plt.bar(features, pca.explained_variance_)
plt.xlabel('PCA feature')
plt.ylabel('variance')
plt.xticks(features)
plt.show()

# %%
from sklearn.pipeline import make_pipeline
from sklearn.cluster import KMeans

# Create scaler: scaler
scaler = StandardScaler()

# Create KMeans instance: kmeans
kmeans = KMeans(n_clusters = 4)

# Create pipeline: pipeline
pipeline = make_pipeline(scaler,kmeans)

# %%
data=X.iloc[:,1:3]

# %%
pipeline.fit(pca_features)

# Calculate the cluster labels: labels
labels = pipeline.predict(X)
# Out:
# /Users/softylines/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(

# %%
ks = range(1, 8)
inertias = []

for k in ks:
    # Create a KMeans instance with k clusters: model
    model = KMeans(n_clusters=k)
    
    # Fit model to samples
    model.fit(X)
    
    # Append the inertia to the list of inertias
    inertias.append(model.inertia_)
    
# Plot ks vs inertias
plt.plot(ks, inertias, '-o')
plt.xlabel('number of clusters, k')
plt.ylabel('inertia')
plt.xticks(ks)
plt.show()

# %% [markdown]
# ##### The best value of k is 4

# %%
kmeans = KMeans(n_clusters= 4)

label = kmeans.fit_predict(X)
 
print(label)
# Out:
# [0 0 0 ... 0 0 0]

# %%
X
# Out:
#       status_type  num_reactions  num_comments  num_shares  num_likes  \
# 0               0            529           512         262        432
# 1               1            150             0           0        150
# 2               0            227           236          57        204
# 3               1            111             0           0        111
# 4               1            213             0           0        204
# ...           ...            ...           ...         ...        ...
# 7045            1             89             0           0         89
# 7046            1             16             0           0         14
# 7047            1              2             0           0          1
# 7048            1            351            12          22        349
# 7049            1             17             0           0         17
#
#       num_loves  num_wows  num_hahas  num_sads  num_angrys
# 0            92         3          1         1           0
# ...

# %%
filtered_label0 = X[X["status_type"] == 0]

# %%
filtered_label1 = X[X["status_type"] == 1]
filtered_label2 = X[X["status_type"] == 2]
filtered_label3 = X[X["status_type"] == 3]
 
#Plotting the results
plt.scatter(filtered_label0.iloc[:,0] , filtered_label0.iloc[:,1])
plt.scatter(filtered_label1.iloc[:,0] , filtered_label1.iloc[:,1] , color = 'green')
plt.scatter(filtered_label2.iloc[:,0] , filtered_label2.iloc[:,1], color = 'red')
plt.scatter(filtered_label3.iloc[:,0] , filtered_label3.iloc[:,1] , color = 'black')
plt.show()
